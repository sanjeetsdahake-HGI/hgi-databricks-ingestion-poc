# %% [markdown]
# ###==================================================
# **Databricks <> Salesforce using Lakeflow Connect | Salesforce Connector **
#
# Creation of
# - Automates connection to Salesforce
# - Auto Incremental data processing
# - Streaming data pipelines.
#
# This approach allows organizations to move data from Salesforce CRM or Data Cloud into a Databricks Lakehouse (Unity Catalog) using streaming tables, enabling near-real-time analytics.
#
# ###==================================================

# %% [markdown]
# ![Screenshot 2026-04-01 172309.png](./images/Screenshot 2026-04-01 172309.png "Screenshot 2026-04-01 172309.png")

# %% [markdown]
# ####=======================================================
# #### Databricks <> BigQuery using Native connector
# ####=======================================================

# %% [markdown]
# ![bg.png](./images/bg.png "bg.png")
