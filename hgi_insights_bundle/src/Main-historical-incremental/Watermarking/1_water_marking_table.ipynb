# %%
# %sql
CREATE TABLE IF NOT EXISTS ingestion_metadata.watermarks (
  source_system STRING,
  object_name STRING,
  last_processed_timestamp TIMESTAMP
)
USING DELTA

# %%
# %sql
INSERT INTO ingestion_metadata.watermarks VALUES
('salesforce','account','1900-01-01'),
('salesforce','contact','1900-01-01'),
('salesforce','opportunity','1900-01-01'),
('bigquery','events','1900-01-01');

# %%
# %sql
SELECT * FROM ingestion_metadata.watermarks

# %%
df = spark.table("`bigquery-connection_catalog`.v4c_bigquery_dataset.event_raw").limit(10)
display(df)
