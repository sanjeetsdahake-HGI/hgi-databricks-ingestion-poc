# %%
# %sql
CREATE TABLE IF NOT EXISTS ingestion_metadata.watermarks (
  source_system STRING,
  object_name STRING,
  last_processed_timestamp TIMESTAMP
)
USING DELTA;

# %%
# %sql
SELECT * FROM ingestion_metadata.watermarks

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list("gcp_auth")

# %%
df = spark.table("`bigquery-connection_catalog`.v4c_bigquery_dataset.event_raw")
display(df.limit(5))

# %%
df = spark.table("`bigquery-connection_catalog`.v4c_bigquery_dataset.event_raw")
df.printSchema()

# %%
display(df_s3.limit(3))

# %%
df_s3 = spark.read.parquet("s3://hgi-databricks-data-lakehouse-dev/landing-zone/salesforce/cust_001/account/historical/2026/03/16/14/part-00000-tid-4946514892614126627-625ea9de-6528-4c70-bcde-58f821c74532-35-1-c000.snappy.parquet")
df_s3.printSchema()

# %%
display(df_campaign.limit(3))

# %%
df_campaign = spark.read.parquet("s3://hgi-databricks-data-lakehouse-dev/landing-zone/salesforce/cust_001/campaign/historical/2026/03/16/14/part-00000-tid-7871827314232466997-d218ac23-5cfd-4bd2-950c-3a8fdae5f0f5-38-1-c000.snappy.parquet")
df_campaign.printSchema()

# %%
display(df_contact.limit(3))

# %%
df_contact = spark.read.parquet("s3://hgi-databricks-data-lakehouse-dev/landing-zone/salesforce/cust_001/contact/historical/2026/03/16/14/part-00000-tid-8197115338134855161-5354b511-91d7-456e-97a8-9faec72d993e-39-1-c000.snappy.parquet")
df_contact.printSchema()

# %%
display(df_opportunity.limit(3))

# %%
df_opportunity = spark.read.parquet("s3://hgi-databricks-data-lakehouse-dev/landing-zone/salesforce/cust_001/opportunity/historical/2026/03/16/14/part-00000-tid-806823193593164416-9eb60752-7091-4375-9d61-b4da8f9bc379-41-1-c000.snappy.parquet")
df_opportunity.printSchema()

# %%
df_user = spark.read.parquet("s3://hgi-databricks-data-lakehouse-dev/landing-zone/salesforce/cust_001/user/historical/2026/03/16/14/part-00000-tid-9212863898457258083-39226d38-fa5e-4cec-8568-3f578e5a4781-40-1-c000.snappy.parquet")
df_user.printSchema()

# %%
display(df_user.limit(3))

# %%
spark.table("`salesforce-catalog`.default.task").printSchema()

# %%
spark.table("bronze.cust_001.crm_tasks").printSchema()

# %% [markdown]
# #Schema In Bronze Layer

# %%
spark.table("bronze.cust_001.crm_accounts").printSchema()
spark.table("bronze.cust_001.crm_campaign_members").printSchema()
spark.table("bronze.cust_001.crm_campaigns").printSchema()
spark.table("bronze.cust_001.crm_contacts").printSchema()
spark.table("bronze.cust_001.crm_events").printSchema()
spark.table("bronze.cust_001.crm_opportunities").printSchema()
spark.table("bronze.cust_001.crm_tasks").printSchema()
spark.table("bronze.cust_001.crm_users").printSchema()

# %%
for table in spark.catalog.listTables("hgi.silver"):
    spark.sql(f"DROP TABLE IF EXISTS hgi.silver.{table.name}")
